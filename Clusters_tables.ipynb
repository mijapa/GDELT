# %%
from ipynb.fs.full.Clusters_map import *
# Out:
# ipynb.fs.full.Clustering_Std_KMEANS:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# /home/micha/anaconda3/envs/geo_env/lib/python3.7/site-packages/geopandas/geodataframe.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %% [markdown]
# ## Clusters

# %%
merged['gdp_per_cap'] = merged.gdp_md_est / merged.pop_est

from IPython.display import display

for c in range(10):
    # print('cluster {}'.format(c), flush=True)
    display('cluster {}'.format(c))
    
    cluster_tab = merged[merged.cluster==c][['iso_a3', 'name', 'continent' ,'pop_est', 'gdp_per_cap']].sort_values(by='name')
    display(cluster_tab)
    cluster_tab.to_latex('text/tables/CLUST/clust{}kmeans.tex'.format(c),
                          na_rep='brak',
                          caption='Klaster {}'.format(c),
                          label='tab:cl{}'.format(c),
                          index=False
                          )
# Out:
# 'cluster 0'
#     iso_a3          name      continent    pop_est  gdp_per_cap
# 76     DZA       Algeria         Africa   40969443     0.014875
# 103    ARM       Armenia           Asia    3045191     0.008637
# 108    AUT       Austria         Europe    8754413     0.047587
# 137    AZE    Azerbaijan           Asia    9961396     0.016855
# 105    BLR       Belarus         Europe    9549747     0.017320
# 25     BOL       Bolivia  South America   11138234     0.007034
# 115    BGR      Bulgaria         Europe    7101510     0.020151
# 9      CHL         Chile  South America   17789267     0.024515
# 119    HRV       Croatia         Europe    4292095     0.021957
# 41     CUB          Cuba  North America   11147407     0.011922
# 153    CYP        Cyprus           Asia    1221549     0.023953
# 152    CYP        Cyprus           Asia    1221549     0.023953
# 144    CZE       Czechia         Europe   10674723     0.032872
# 134    DNK       Denmark         Europe    5605948     0.047236
# 157    ETH      Ethiopia         Africa  105350020     0.001658
# 142    FIN       Finland         Europe    5491218     0.040817
# 53     GHA         Ghana         Africa   27499924     0.004393
# 33     GTM     Guatemala  North America   15460732     0.008525
# 46     MLI          Mali         Africa   17885245     0.002130
# 154    MAR       Morocco         Africa   33986655     0.008321
# 87     MMR       Myanmar           Asia   55123814     0.005644
# 151    CYP     N. Cyprus           Asia     265100     0.013580
# 150    CYP     N. Cyprus           Asia     265100     0.013580
# 95     NPL         Nepal           Asia   29384297     0.002434
# 89     PRK   North Korea           Asia   25248140     0.001584
# 19     NOR        Norway         Europe    5320045     0.068552
# 82     OMN          Oman           Asia    3424386     0.050549
# 26     PER          Peru  South America   31036656     0.013223
# 124    PRT      Portugal         Europe   10839514     0.027409
# 20     ZAF  South Africa         Africa   54841552     0.013477
# 130    LKA     Sri Lanka           Asia   22409381     0.010563
# 13     SDN         Sudan         Africa   37345935     0.004721
# 132    TWN        Taiwan           Asia   23508428     0.047940
# 85     THA      Thailand           Asia   68414135     0.016970
# 75     TUN       Tunisia         Africa   11403800     0.011470
# 88     VNM       Vietnam           Asia   96160163     0.006187
# 148    YEM         Yemen           Asia   28036829     0.002620
# 42     ZWE      Zimbabwe         Africa   13805084     0.002052
# 'cluster 1'
#     iso_a3                  name      continent    pop_est  gdp_per_cap
# 8      ARG             Argentina  South America   44293293     0.019854
# 93     BGD            Bangladesh           Asia  157826578     0.003982
# 122    BEL               Belgium         Europe   11491346     0.044259
# 27     COL              Colombia  South America   47698524     0.014424
# 77     JOR                Jordan           Asia   10248069     0.008410
# 12     KEN                 Kenya         Africa   47615739     0.003207
# 71     LBN               Lebanon           Asia    6229794     0.013670
# 140    MYS              Malaysia           Asia   31381992     0.027500
# 123    NLD           Netherlands         Europe   17084719     0.050970
# 128    NZL           New Zealand        Oceania    4510327     0.038756
# 104    SWE                Sweden         Europe    9960487     0.050008
# 78     ARE  United Arab Emirates           Asia    6072475     0.109873
# 35     VEN             Venezuela  South America   31304016     0.014969
# 'cluster 2'
#     iso_a3          name      continent    pop_est  gdp_per_cap
# 97     AFG   Afghanistan           Asia   34124811     0.001878
# 24     BRA        Brazil  South America  207353391     0.014859
# 155    EGY         Egypt         Africa   97041072     0.011387
# 116    GRC        Greece         Europe   10768477     0.026977
# 126    IRL       Ireland         Europe    5011102     0.064257
# 73     PSE     Palestine           Asia    4543126     0.004671
# 139    PHL   Philippines           Asia  104256076     0.007692
# 107    POL        Poland         Europe   38476269     0.027342
# 149    SAU  Saudi Arabia           Asia   28571770     0.060584
# 90     KOR   South Korea           Asia   51181299     0.037690
# 120    CHE   Switzerland         Europe    8236303     0.060258
# 102    SYR         Syria           Asia   18028549     0.002789
# 'cluster 3'
#     iso_a3             name      continent   pop_est  gdp_per_cap
# 18     BHS          Bahamas  North America    329988     0.027474
# 59     BFA     Burkina Faso         Africa  20107509     0.001641
# 84     KHM         Cambodia           Asia  16204486     0.003637
# 51     CMR         Cameroon         Africa  24994885     0.003090
# 14     TCD             Chad         Africa  12075985     0.002533
# 54     CIV    Côte d'Ivoire         Africa  24184810     0.003602
# 10     COD  Dem. Rep. Congo         Africa  83301151     0.000792
# 16     DOM   Dominican Rep.  North America  10734247     0.015083
# 32     SLV      El Salvador  North America   6172011     0.008877
# 113    EST          Estonia         Europe   1251581     0.030921
# 74     GMB           Gambia         Africa   2051363     0.001651
# 55     GIN           Guinea         Africa  12413867     0.001295
# 36     GUY           Guyana  South America    737718     0.008259
# 15     HTI            Haiti  North America  10646714     0.001817
# 99     KGZ       Kyrgyzstan           Asia   5789122     0.003629
# 57     LBR          Liberia         Africa   4689021     0.000828
# 121    LUX       Luxembourg         Europe    594130     0.098867
# 65     MWI           Malawi         Africa  19196246     0.001104
# 110    MDA          Moldova         Europe   3474121     0.005337
# 66     MOZ       Mozambique         Africa  26573706     0.001317
# 30     NIC        Nicaragua  North America   6025951     0.005568
# 49     NER            Niger         Africa  19245344     0.001047
# 28     PAN           Panama  North America   3753142     0.024811
# 160    RWA           Rwanda         Africa  11901484     0.001846
# 164    SSD         S. Sudan         Africa  13026129     0.001603
# 45     SEN          Senegal         Africa  14668522     0.002708
# 143    SVK         Slovakia         Europe   5445829     0.030996
# 1      TZA         Tanzania         Africa  53950935     0.002791
# 23     URY          Uruguay  South America   3360148     0.021800
# 5      UZB       Uzbekistan           Asia  29748859     0.006800
# 64     ZMB           Zambia         Africa  15972000     0.004080
# 'cluster 4'
#     iso_a3       name      continent     pop_est  gdp_per_cap
# 92     IND      India           Asia  1281935911     0.006803
# 7      IDN  Indonesia           Asia   260580739     0.011620
# 133    ITA      Italy         Europe    62137802     0.035743
# 146    JPN      Japan           Asia   126451398     0.039003
# 156    LBY      Libya         Africa     6653210     0.013661
# 22     MEX     Mexico  North America   124574795     0.018519
# 50     NGA    Nigeria         Africa   190632261     0.005713
# 96     PAK   Pakistan           Asia   204924861     0.004822
# 125    ESP      Spain         Europe    48958159     0.034519
# 'cluster 5'
#     iso_a3        name      continent   pop_est  gdp_per_cap
# 118    ALB     Albania         Europe   3047987     0.011122
# 68     AGO      Angola         Africa  29310273     0.006448
# 39     ECU     Ecuador  South America  16290913     0.011196
# 31     HND    Honduras  North America   9038741     0.004778
# 109    HUN     Hungary         Europe   9850845     0.027165
# 40     JAM     Jamaica  North America   2990561     0.008490
# 4      KAZ  Kazakhstan           Asia  18556698     0.024827
# 80     KWT      Kuwait           Asia   2875422     0.104715
# 112    LVA      Latvia         Europe   1944643     0.026046
# 111    LTU   Lithuania         Europe   2823859     0.030320
# 161    MKD   Macedonia         Europe   2103721     0.014032
# 79     QAT       Qatar           Asia   2314307     0.144536
# 162    SRB      Serbia         Europe   7111024     0.014316
# 11     SOM     Somalia         Africa   7531386     0.000627
# 159    UGA      Uganda         Africa  39570125     0.002146
# 'cluster 6'
#     iso_a3            name continent     pop_est  gdp_per_cap
# 131    CHN           China      Asia  1379302771     0.015327
# 101    IRN            Iran      Asia    82021564     0.017788
# 17     RUS          Russia    Europe   142257519     0.026325
# 135    GBR  United Kingdom    Europe    64769452     0.043045
# 'cluster 7'
#   iso_a3                      name      continent    pop_est  gdp_per_cap
# 3    USA  United States of America  North America  326625791     0.056823
# 'cluster 8'
#     iso_a3                  name      continent   pop_est  gdp_per_cap
# 34     BLZ                Belize  North America    360346     0.008570
# 48     BEN                 Benin         Africa  11038805     0.002202
# 94     BTN                Bhutan           Asia    758288     0.008482
# 43     BWA              Botswana         Africa   2214858     0.016209
# 141    BRN                Brunei           Asia    443593     0.076038
# 69     BDI               Burundi         Africa  11466756     0.000688
# 60     CAF  Central African Rep.         Africa   5625118     0.000570
# 61     COG                 Congo         Africa   4954674     0.006109
# 29     CRI            Costa Rica  North America   4930258     0.016076
# 158    DJI              Djibouti         Africa    865267     0.003866
# 63     GNQ            Eq. Guinea         Africa    778358     0.040817
# 145    ERI               Eritrea         Africa   5918919     0.001549
# 0      FJI                  Fiji        Oceania    920938     0.009093
# 62     GAB                 Gabon         Africa   1772255     0.020302
# 138    GEO               Georgia           Asia   4926330     0.007565
# 56     GNB         Guinea-Bissau         Africa   1792338     0.001591
# 136    ISL               Iceland         Europe    339747     0.047535
# 86     LAO                  Laos           Asia   7126706     0.005747
# 21     LSO               Lesotho         Africa   1958042     0.003074
# 72     MDG            Madagascar         Africa  25054161     0.001471
# 47     MRT            Mauritania         Africa   3758571     0.004446
# 91     MNG              Mongolia           Asia   3068243     0.012059
# 44     NAM               Namibia         Africa   2484780     0.010460
# 6      PNG      Papua New Guinea        Oceania   6909701     0.004055
# 147    PRY              Paraguay  South America   6943739     0.009313
# 58     SLE          Sierra Leone         Africa   6163195     0.001726
# 127    SLB           Solomon Is.        Oceania    647581     0.001850
# 37     SUR              Suriname  South America    591919     0.014439
# 98     TJK            Tajikistan           Asia   8468555     0.003048
# 52     TGO                  Togo         Africa   7965055     0.001458
# 163    TTO   Trinidad and Tobago  North America   1218208     0.035766
# 100    TKM          Turkmenistan           Asia   5351277     0.017700
# 83     VUT               Vanuatu        Oceania    282814     0.002556
# 67     SWZ              eSwatini         Africa   1467152     0.007538
# 'cluster 9'
#     iso_a3       name      continent   pop_est  gdp_per_cap
# 129    AUS  Australia        Oceania  23232413     0.051178
# 2      CAN     Canada  North America  35623680     0.046991
# 38     FRA     France         Europe  67106161     0.040220
# 114    DEU    Germany         Europe  80594017     0.049371
# 81     IRQ       Iraq           Asia  39192111     0.015225
# 70     ISR     Israel           Asia   8299706     0.035784
# 117    TUR     Turkey           Asia  80845215     0.020657
# 106    UKR    Ukraine         Europe  44033874     0.008007

# %% [markdown]
# ## Clusters on standardised data

# %%
merged_std['gdp_per_cap'] = merged_std.gdp_md_est / merged_std.pop_est

# pd.options.display.float_format = '{:.4f}'.format
pd.options.display.float_format = '{:0.4}'.format


for c in range(10):
    # print('cluster {}'.format(c), flush=True)
    display('cluster {}'.format(c))
    cluster = merged_std[merged_std.cluster==c]
    ilosc = cluster['iso_a3'].count()
    display("ilość krajów w klastrze: {}".format(ilosc))

    cluster_tab = cluster[['iso_a3', 'name', 'continent' ,'pop_est', 'gdp_per_cap']].sort_values(by='name')
    display(cluster_tab)
    cluster_tab.to_latex('text/tables/CLUST/clust{}stdkmeans.tex'.format(c),
                          na_rep='brak',
                          caption='Klaster {} - dane standaryzowane'.format(c),
                          label='tab:cl{}std'.format(c),
                          index=False
                          )

    data= {'mean':[], 'median':[], 'std':[], 'min':[], 'max':[]}
    cluster_desc = pd.DataFrame(data)

    for param in {'pop_est',
                  'gdp_per_cap',
                  'Events',
                  'sumNumMentions',
                  'materialConfCoop',
                  'verbalConfCoop',
                  'avgAvgTone',
                  'avgGoldstein',
                  'fightCount',
                  'expressCount'
                  }:
        row = {
           'mean':cluster[param].mean(),
           'median':cluster[param].median(),
           'std':cluster[param].std(),
           'min':cluster[param].min(),
           'max':cluster[param].max(),
           }

        cluster_desc = cluster_desc.append(pd.Series(row).rename(param))

    display(cluster_desc)
    cluster_desc.to_latex('text/tables/CLUST/desc/clust{}std_desc.tex'.format(c),
                          na_rep='brak',
                          caption='Parametry klastra {} - dane standaryzowane'.format(c),
                          label='tab:cl{}std_desc'.format(c),
                          bold_rows=True
                          )
# Out:
# 'cluster 0'
# 'ilość krajów w klastrze: 1'
#   iso_a3                      name      continent    pop_est  gdp_per_cap
# 3    USA  United States of America  North America  326625791      0.05682
#                       mean    median  std       min       max
# gdp_per_cap        0.05682   0.05682  nan   0.05682   0.05682
# avgGoldstein        0.3709    0.3709  nan    0.3709    0.3709
# verbalConfCoop       0.126     0.126  nan     0.126     0.126
# avgAvgTone           -2.26     -2.26  nan     -2.26     -2.26
# pop_est          3.266e+08 3.266e+08  nan 3.266e+08 3.266e+08
# sumNumMentions   3.472e+06 3.472e+06  nan 3.472e+06 3.472e+06
# fightCount       5.772e+04 5.772e+04  nan 5.772e+04 5.772e+04
# expressCount     1.979e+04 1.979e+04  nan 1.979e+04 1.979e+04
# materialConfCoop    0.1571    0.1571  nan    0.1571    0.1571
# Events           8.198e+05 8.198e+05  nan 8.198e+05 8.198e+05
# 'cluster 1'
# 'ilość krajów w klastrze: 18'
#     iso_a3                  name      continent   pop_est  gdp_per_cap
# 48     BEN                 Benin         Africa  11038805     0.002202
# 94     BTN                Bhutan           Asia    758288     0.008482
# 141    BRN                Brunei           Asia    443593      0.07604
# 29     CRI            Costa Rica  North America   4930258      0.01608
# 16     DOM        Dominican Rep.  North America  10734247      0.01508
# 113    EST               Estonia         Europe   1251581      0.03092
# 136    ISL               Iceland         Europe    339747      0.04754
# 86     LAO                  Laos           Asia   7126706     0.005747
# 121    LUX            Luxembourg         Europe    594130      0.09887
# 161    MKD             Macedonia         Europe   2103721      0.01403
# 72     MDG            Madagascar         Africa  25054161     0.001471
# 82     OMN                  Oman           Asia   3424386      0.05055
# 79     QAT                 Qatar           Asia   2314307       0.1445
# 100    TKM          Turkmenistan           Asia   5351277       0.0177
# 78     ARE  United Arab Emirates           Asia   6072475       0.1099
# 23     URY               Uruguay  South America   3360148       0.0218
# 5      UZB            Uzbekistan           Asia  29748859       0.0068
# 83     VUT               Vanuatu        Oceania    282814     0.002556
#                       mean    median       std       min       max
# gdp_per_cap        0.03724   0.01689   0.04268  0.001471    0.1445
# avgGoldstein         1.943     1.887    0.3279     1.476     2.749
# verbalConfCoop     0.08207   0.07921   0.02208   0.04769    0.1257
# avgAvgTone         -0.2539   -0.2941    0.3794   -0.9221    0.4018
# pop_est          6.385e+06 3.392e+06 8.375e+06 2.828e+05 2.975e+07
# sumNumMentions   1.195e+04 7.182e+03 1.304e+04  1.42e+03 5.238e+04
# fightCount           65.83      30.5     97.29       2.0     393.0
# expressCount         32.83      22.5     37.63       1.0     160.0
# materialConfCoop    0.0653   0.06346   0.01573    0.0371   0.09901
# Events           2.421e+03  1.34e+03 2.923e+03     261.0 1.168e+04
# 'cluster 2'
# 'ilość krajów w klastrze: 12'
#     iso_a3       name      continent     pop_est  gdp_per_cap
# 25     BOL    Bolivia  South America    11138234     0.007034
# 69     BDI    Burundi         Africa    11466756    0.0006883
# 9      CHL      Chile  South America    17789267      0.02451
# 74     GMB     Gambia         Africa     2051363     0.001651
# 55     GIN     Guinea         Africa    12413867     0.001295
# 92     IND      India           Asia  1281935911     0.006803
# 77     JOR     Jordan           Asia    10248069      0.00841
# 71     LBN    Lebanon           Asia     6229794      0.01367
# 50     NGA    Nigeria         Africa   190632261     0.005713
# 96     PAK   Pakistan           Asia   204924861     0.004822
# 73     PSE  Palestine           Asia     4543126     0.004671
# 107    POL     Poland         Europe    38476269      0.02734
#                       mean    median       std       min       max
# gdp_per_cap       0.008885  0.006258  0.008724 0.0006883   0.02734
# avgGoldstein        0.2349    0.3253    0.4179     -0.46    0.7515
# verbalConfCoop      0.1755    0.1656   0.02456    0.1474    0.2346
# avgAvgTone          -2.429    -2.316    0.6133    -4.099    -1.697
# pop_est          1.493e+08 1.194e+07 3.639e+08 2.051e+06 1.282e+09
# sumNumMentions   8.594e+04 7.422e+04 7.127e+04 7.243e+03   2.3e+05
# fightCount       1.113e+03 1.016e+03 1.023e+03      71.0 2.953e+03
# expressCount         329.2     213.5     385.2      13.0 1.396e+03
# materialConfCoop    0.1358    0.1336   0.02872    0.0923     0.187
# Events           1.906e+04 1.575e+04 1.697e+04  1.54e+03 5.170e+04
# 'cluster 3'
# 'ilość krajów w klastrze: 45'
#     iso_a3           name      continent    pop_est  gdp_per_cap
# 118    ALB        Albania         Europe    3047987      0.01112
# 68     AGO         Angola         Africa   29310273     0.006448
# 8      ARG      Argentina  South America   44293293      0.01985
# 103    ARM        Armenia           Asia    3045191     0.008637
# 108    AUT        Austria         Europe    8754413      0.04759
# 43     BWA       Botswana         Africa    2214858      0.01621
# 24     BRA         Brazil  South America  207353391      0.01486
# 115    BGR       Bulgaria         Europe    7101510      0.02015
# 27     COL       Colombia  South America   47698524      0.01442
# 41     CUB           Cuba  North America   11147407      0.01192
# 153    CYP         Cyprus           Asia    1221549      0.02395
# 152    CYP         Cyprus           Asia    1221549      0.02395
# 144    CZE        Czechia         Europe   10674723      0.03287
# 142    FIN        Finland         Europe    5491218      0.04082
# 62     GAB          Gabon         Africa    1772255       0.0203
# 116    GRC         Greece         Europe   10768477      0.02698
# 56     GNB  Guinea-Bissau         Africa    1792338     0.001591
# 15     HTI          Haiti  North America   10646714     0.001817
# 109    HUN        Hungary         Europe    9850845      0.02717
# 7      IDN      Indonesia           Asia  260580739      0.01162
# 126    IRL        Ireland         Europe    5011102      0.06426
# 146    JPN          Japan           Asia  126451398        0.039
# 57     LBR        Liberia         Africa    4689021    0.0008277
# 156    LBY          Libya         Africa    6653210      0.01366
# 111    LTU      Lithuania         Europe    2823859      0.03032
# 65     MWI         Malawi         Africa   19196246     0.001104
# 140    MYS       Malaysia           Asia   31381992       0.0275
# 110    MDA        Moldova         Europe    3474121     0.005337
# 66     MOZ     Mozambique         Africa   26573706     0.001317
# 87     MMR        Myanmar           Asia   55123814     0.005644
# 150    CYP      N. Cyprus           Asia     265100      0.01358
# 151    CYP      N. Cyprus           Asia     265100      0.01358
# 30     NIC      Nicaragua  North America    6025951     0.005568
# 19     NOR         Norway         Europe    5320045      0.06855
# 28     PAN         Panama  North America    3753142      0.02481
# 125    ESP          Spain         Europe   48958159      0.03452
# 13     SDN          Sudan         Africa   37345935     0.004721
# 37     SUR       Suriname  South America     591919      0.01444
# 104    SWE         Sweden         Europe    9960487      0.05001
# 132    TWN         Taiwan           Asia   23508428      0.04794
# 75     TUN        Tunisia         Africa   11403800      0.01147
# 159    UGA         Uganda         Africa   39570125     0.002146
# 35     VEN      Venezuela  South America   31304016      0.01497
# 64     ZMB         Zambia         Africa   15972000      0.00408
# 42     ZWE       Zimbabwe         Africa   13805084     0.002052
#                       mean    median       std       min       max
# gdp_per_cap        0.01964   0.01444   0.01692 0.0008277   0.06855
# avgGoldstein        0.9784    0.9816    0.2467    0.4936     1.401
# verbalConfCoop      0.1281    0.1251   0.01571    0.1012      0.19
# avgAvgTone           -1.61    -1.557    0.4971    -2.507   -0.2297
# pop_est          2.683e+07  9.96e+06 5.072e+07 2.651e+05 2.606e+08
# sumNumMentions   4.708e+04 3.398e+04 4.922e+04     941.0  1.95e+05
# fightCount           379.4     200.0     494.1       0.0 2.667e+03
# expressCount         188.7     112.0     216.0       3.0     933.0
# materialConfCoop     0.111    0.1164   0.02144   0.01075    0.1352
# Events           8.935e+03 5.868e+03 9.358e+03     279.0 3.885e+04
# 'cluster 4'
# 'ilość krajów w klastrze: 26'
#     iso_a3                 name      continent    pop_est  gdp_per_cap
# 18     BHS              Bahamas  North America     329988      0.02747
# 93     BGD           Bangladesh           Asia  157826578     0.003982
# 34     BLZ               Belize  North America     360346      0.00857
# 10     COD      Dem. Rep. Congo         Africa   83301151    0.0007924
# 32     SLV          El Salvador  North America    6172011     0.008877
# 33     GTM            Guatemala  North America   15460732     0.008525
# 36     GUY               Guyana  South America     737718     0.008259
# 80     KWT               Kuwait           Asia    2875422       0.1047
# 46     MLI                 Mali         Africa   17885245      0.00213
# 22     MEX               Mexico  North America  124574795      0.01852
# 91     MNG             Mongolia           Asia    3068243      0.01206
# 95     NPL                Nepal           Asia   29384297     0.002434
# 123    NLD          Netherlands         Europe   17084719      0.05097
# 89     PRK          North Korea           Asia   25248140     0.001584
# 6      PNG     Papua New Guinea        Oceania    6909701     0.004055
# 26     PER                 Peru  South America   31036656      0.01322
# 139    PHL          Philippines           Asia  104256076     0.007692
# 160    RWA               Rwanda         Africa   11901484     0.001846
# 164    SSD             S. Sudan         Africa   13026129     0.001603
# 149    SAU         Saudi Arabia           Asia   28571770      0.06058
# 143    SVK             Slovakia         Europe    5445829        0.031
# 127    SLB          Solomon Is.        Oceania     647581      0.00185
# 20     ZAF         South Africa         Africa   54841552      0.01348
# 98     TJK           Tajikistan           Asia    8468555     0.003048
# 163    TTO  Trinidad and Tobago  North America    1218208      0.03577
# 67     SWZ             eSwatini         Africa    1467152     0.007538
#                       mean    median       std       min       max
# gdp_per_cap        0.01694  0.008392   0.02373 0.0007924    0.1047
# avgGoldstein        0.5751    0.5574    0.2709   -0.0144     1.054
# verbalConfCoop      0.1035    0.1078   0.02079   0.04282    0.1311
# avgAvgTone          -2.082    -2.021    0.6532    -3.673    -1.062
# pop_est          2.893e+07 1.246e+07 4.202e+07   3.3e+05 1.578e+08
# sumNumMentions   3.249e+04 1.279e+04 4.267e+04     895.0 1.926e+05
# fightCount           424.1     173.0     629.0       5.0 2.417e+03
# expressCount         145.7      62.5     196.8       4.0     749.0
# materialConfCoop    0.1634    0.1614   0.02405    0.1272    0.2331
# Events           6.648e+03 2.708e+03 8.592e+03     206.0 3.564e+04
# 'cluster 5'
# 'ilość krajów w klastrze: 33'
#     iso_a3           name      continent    pop_est  gdp_per_cap
# 76     DZA        Algeria         Africa   40969443      0.01487
# 137    AZE     Azerbaijan           Asia    9961396      0.01686
# 105    BLR        Belarus         Europe    9549747      0.01732
# 122    BEL        Belgium         Europe   11491346      0.04426
# 84     KHM       Cambodia           Asia   16204486     0.003637
# 119    HRV        Croatia         Europe    4292095      0.02196
# 54     CIV  Côte d'Ivoire         Africa   24184810     0.003602
# 134    DNK        Denmark         Europe    5605948      0.04724
# 158    DJI       Djibouti         Africa     865267     0.003866
# 39     ECU        Ecuador  South America   16290913       0.0112
# 155    EGY          Egypt         Africa   97041072      0.01139
# 63     GNQ     Eq. Guinea         Africa     778358      0.04082
# 145    ERI        Eritrea         Africa    5918919     0.001549
# 157    ETH       Ethiopia         Africa  105350020     0.001658
# 0      FJI           Fiji        Oceania     920938     0.009093
# 53     GHA          Ghana         Africa   27499924     0.004393
# 133    ITA          Italy         Europe   62137802      0.03574
# 40     JAM        Jamaica  North America    2990561      0.00849
# 4      KAZ     Kazakhstan           Asia   18556698      0.02483
# 99     KGZ     Kyrgyzstan           Asia    5789122     0.003629
# 112    LVA         Latvia         Europe    1944643      0.02605
# 154    MAR        Morocco         Africa   33986655     0.008321
# 128    NZL    New Zealand        Oceania    4510327      0.03876
# 124    PRT       Portugal         Europe   10839514      0.02741
# 45     SEN        Senegal         Africa   14668522     0.002708
# 162    SRB         Serbia         Europe    7111024      0.01432
# 58     SLE   Sierra Leone         Africa    6163195     0.001726
# 90     KOR    South Korea           Asia   51181299      0.03769
# 130    LKA      Sri Lanka           Asia   22409381      0.01056
# 120    CHE    Switzerland         Europe    8236303      0.06026
# 1      TZA       Tanzania         Africa   53950935     0.002791
# 52     TGO           Togo         Africa    7965055     0.001458
# 88     VNM        Vietnam           Asia   96160163     0.006187
#                       mean    median       std       min       max
# gdp_per_cap        0.01711    0.0112    0.0161  0.001458   0.06026
# avgGoldstein         1.394     1.405    0.2514    0.9687     2.107
# verbalConfCoop     0.09955    0.1004   0.01481   0.06468    0.1241
# avgAvgTone         -0.9773    -1.015    0.4199    -1.774   -0.2663
# pop_est           2.38e+07 1.084e+07 2.907e+07 7.784e+05 1.054e+08
# sumNumMentions   3.961e+04 3.063e+04 4.565e+04 1.952e+03 2.152e+05
# fightCount           267.9     143.0     312.8       9.0 1.529e+03
# expressCount         148.4      69.0     189.7       2.0     877.0
# materialConfCoop   0.09779    0.1005   0.01777   0.06512    0.1308
# Events           7.575e+03 5.457e+03 8.408e+03     407.0 3.717e+04
# 'cluster 6'
# 'ilość krajów w klastrze: 9'
#     iso_a3          name continent   pop_est  gdp_per_cap
# 97     AFG   Afghanistan      Asia  34124811     0.001878
# 59     BFA  Burkina Faso    Africa  20107509     0.001641
# 51     CMR      Cameroon    Africa  24994885      0.00309
# 12     KEN         Kenya    Africa  47615739     0.003207
# 21     LSO       Lesotho    Africa   1958042     0.003074
# 49     NER         Niger    Africa  19245344     0.001047
# 11     SOM       Somalia    Africa   7531386    0.0006266
# 102    SYR         Syria      Asia  18028549     0.002789
# 148    YEM         Yemen      Asia  28036829      0.00262
#                       mean    median       std       min       max
# gdp_per_cap       0.002219   0.00262  0.000956 0.0006266  0.003207
# avgGoldstein       -0.7943   -0.5985    0.4934    -1.679   -0.2817
# verbalConfCoop      0.1111     0.112   0.02074   0.08095    0.1438
# avgAvgTone          -3.785    -3.754    0.6074    -4.501    -2.797
# pop_est           2.24e+07 2.011e+07 1.362e+07 1.958e+06 4.762e+07
# sumNumMentions   4.079e+04 2.249e+04  4.22e+04 5.154e+03 1.235e+05
# fightCount       1.576e+03 1.031e+03  1.79e+03     157.0 5.644e+03
# expressCount         120.1      46.0     141.5      12.0     425.0
# materialConfCoop    0.2495    0.2284   0.04484    0.1877    0.3138
# Events           8.799e+03 5.091e+03 9.324e+03 1.071e+03 2.747e+04
# 'cluster 7'
# 'ilość krajów w klastrze: 10'
#     iso_a3            name      continent     pop_est  gdp_per_cap
# 129    AUS       Australia        Oceania    23232413      0.05118
# 2      CAN          Canada  North America    35623680      0.04699
# 131    CHN           China           Asia  1379302771      0.01533
# 38     FRA          France         Europe    67106161      0.04022
# 114    DEU         Germany         Europe    80594017      0.04937
# 70     ISR          Israel           Asia     8299706      0.03578
# 17     RUS          Russia         Europe   142257519      0.02633
# 117    TUR          Turkey           Asia    80845215      0.02066
# 106    UKR         Ukraine         Europe    44033874     0.008007
# 135    GBR  United Kingdom         Europe    64769452      0.04304
#                       mean    median       std       min       max
# gdp_per_cap        0.03369     0.038   0.01522  0.008007   0.05118
# avgGoldstein         0.837    0.9602    0.4481   0.01099     1.353
# verbalConfCoop      0.1226    0.1221   0.01468   0.09992    0.1447
# avgAvgTone           -2.17    -2.162    0.4663    -3.204    -1.434
# pop_est          1.926e+08 6.594e+07 4.186e+08   8.3e+06 1.379e+09
# sumNumMentions   4.407e+05 3.719e+05 1.646e+05 3.002e+05 7.507e+05
# fightCount       4.979e+03 5.012e+03 1.715e+03 2.803e+03  7.55e+03
# expressCount     1.971e+03 1.931e+03     818.7     912.0 3.193e+03
# materialConfCoop    0.1264    0.1191   0.02289   0.09908    0.1632
# Events           9.174e+04 7.546e+04 3.383e+04 6.282e+04 1.625e+05
# 'cluster 8'
# 'ilość krajów w klastrze: 2'
#     iso_a3  name continent   pop_est  gdp_per_cap
# 101    IRN  Iran      Asia  82021564      0.01779
# 81     IRQ  Iraq      Asia  39192111      0.01523
#                       mean    median       std       min       max
# gdp_per_cap        0.01651   0.01651  0.001812   0.01523   0.01779
# avgGoldstein        -1.837    -1.837   0.06262    -1.881    -1.793
# verbalConfCoop      0.1825    0.1825   0.02016    0.1683    0.1968
# avgAvgTone          -4.501    -4.501   0.01991    -4.515    -4.487
# pop_est          6.061e+07 6.061e+07 3.028e+07 3.919e+07 8.202e+07
# sumNumMentions   5.195e+05 5.195e+05 2.915e+05 3.134e+05 7.256e+05
# fightCount       2.398e+04 2.398e+04 1.295e+04 1.483e+04 3.314e+04
# expressCount     1.372e+03 1.372e+03 1.224e+03     507.0 2.238e+03
# materialConfCoop    0.2898    0.2898   0.01858    0.2766    0.3029
# Events           1.216e+05 1.216e+05  6.94e+04 7.254e+04 1.707e+05
# 'cluster 9'
# 'ilość krajów w klastrze: 9'
#     iso_a3                  name      continent   pop_est  gdp_per_cap
# 60     CAF  Central African Rep.         Africa   5625118    0.0005699
# 14     TCD                  Chad         Africa  12075985     0.002533
# 61     COG                 Congo         Africa   4954674     0.006109
# 138    GEO               Georgia           Asia   4926330     0.007565
# 31     HND              Honduras  North America   9038741     0.004778
# 47     MRT            Mauritania         Africa   3758571     0.004446
# 44     NAM               Namibia         Africa   2484780      0.01046
# 147    PRY              Paraguay  South America   6943739     0.009313
# 85     THA              Thailand           Asia  68414135      0.01697
#                       mean    median       std       min       max
# gdp_per_cap       0.006972  0.006109  0.004881 0.0005699   0.01697
# avgGoldstein         1.026      1.05    0.4021    0.4509     1.704
# verbalConfCoop     0.07024   0.07879   0.02749       0.0   0.09029
# avgAvgTone          -2.858    -2.784    0.5661    -3.863    -2.018
# pop_est          1.314e+07 5.625e+06 2.093e+07 2.485e+06 6.841e+07
# sumNumMentions   1.183e+04 6.283e+03 1.291e+04      66.0 4.188e+04
# fightCount           131.3      84.0     118.0       0.0     348.0
# expressCount         65.22      37.0     99.05       0.0     314.0
# materialConfCoop    0.1194    0.1277   0.05256       0.0    0.1757
# Events           2.373e+03 1.253e+03 2.592e+03      20.0 8.423e+03
