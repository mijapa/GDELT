# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from ipynb.fs.full.Clustering_Std_KMEANS import *
# Out:
# ipynb.fs.full.Clustering_Std_KMEANS:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
plt.scatter(points[:, 3], points[:, 2], c=clusters_id,
            cmap='nipy_spectral');

# %%
globalA['cluster'] = km.labels_
globalA
# Out:
# /home/micha/anaconda3/envs/geo_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      Events  sumNumMentions  materialConfCoop  verbalConfCoop  avgAvgTone  \
# 0      7038           34667          0.070190        0.108127   -1.773741
# 1     62821          307088          0.121377        0.118082   -2.313894
# 2       531            2710          0.043315        0.039548    1.555979
# 3      6183           27918          0.129387        0.133269   -2.076521
# 4      1972            9617          0.113590        0.147566   -1.904928
# ..      ...             ...               ...             ...         ...
# ...

# %%
g = sns.pairplot(globalA, hue="cluster");
g.fig.subplots_adjust(top=0.95)
g.fig.suptitle('Countries in 10 clusters visualization', fontsize=16)
# g.figure.set_size_inches(20,8)
# Out:
# /home/micha/anaconda3/envs/geo_env/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 0.98, 'Countries in 10 clusters visualization')

# %%
globalA.drop(['cluster'], axis=1, inplace=True)
# Out:
# /home/micha/anaconda3/envs/geo_env/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
scaled_points= pd.DataFrame(data=scaled_points, index=None, columns=globalA.columns)
scaled_points['cluster']= km.labels_
scaled_points
# Out:
#        Events  sumNumMentions  materialConfCoop  verbalConfCoop  avgAvgTone  \
# 0   -0.105851       -0.095257         -0.739448        0.027811   -0.286076
# 1    0.179180        0.117164          0.151184        0.283374   -0.732023
# 2   -0.139100       -0.120176         -1.207085       -1.732886    2.462917
# 3   -0.110220       -0.100520          0.290565        0.673286   -0.536049
# 4   -0.131737       -0.114790          0.015703        1.040353   -0.394383
# ..        ...             ...               ...             ...         ...
# 214 -0.135681       -0.118321         -0.858760       -0.458983    0.583156
# 215 -0.140387       -0.121555         -1.773655        2.128880    0.988686
# 216  4.047111        2.585220          0.773470        0.486114   -0.687375
# 217 -0.045419       -0.051398          1.938882        0.127401   -1.524730
# 218 -0.140479       -0.121181         -1.027425       -0.682522    1.307921
#
#      avgGoldstein  fightCount  expressCount  cluster
# ...

# %%
g = sns.pairplot(scaled_points, hue="cluster");
g.fig.subplots_adjust(top=0.95)
g.fig.suptitle('Countries in 10 clusters visualization, scale standardized', fontsize=16)
# g.figure.set_size_inches(20,8)
# Out:
# /home/micha/anaconda3/envs/geo_env/lib/python3.7/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 0.98, 'Countries in 10 clusters visualization, scale standardized')
