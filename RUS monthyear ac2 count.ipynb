# %%
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline

sns.set_style("darkgrid")
RUSmonthyearAc2 = pd.read_csv('queries_results/RUS/RUS monthyear ac2 count.csv', header = 0,sep=' *, *')
RUSmonthyearAc2["Time"]=pd.to_datetime(RUSmonthyearAc2['MonthYear'], format='%Y%m').dt.strftime('%Y-%m')
# Out:
# /home/micha/anaconda3/envs/geo_env/lib/python3.7/site-packages/ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
s = RUSmonthyearAc2.groupby("Actor2CountryCode").sum().sort_values(by="Count", ascending=False).head(20)
g = sns.barplot(s.index, s.Count, palette='rainbow')
g.set_title("Actor2 Country Code pair for RUS as Actor1 since 2015")
g.set(ylabel='Count')
g.figure.set_size_inches(20,8)
plt.savefig('text/fig/RUS/RUSactor2Pair.png', bbox_inches='tight')

# %%
s = RUSmonthyearAc2.groupby("Actor2CountryCode").sum().sort_values(by="Count", ascending=False).head(20)[1:]
g = sns.barplot(s.index, s.Count, palette='rainbow')
g.set_title("Actor2 Country Code pair for RUS as Actor1 since 2015 (after RUS)")
g.set(ylabel='Count')
g.figure.set_size_inches(20,8)

# %%
ile = 8
cols = RUSmonthyearAc2.groupby("Actor2CountryCode", as_index=False).sum().sort_values(by="Count", ascending=False).head(ile)['Actor2CountryCode']
s  = RUSmonthyearAc2.loc[RUSmonthyearAc2["Actor2CountryCode"].isin(cols)]
s = s.groupby(["Time","Actor2CountryCode"]).agg({'Count':'sum'})

g = s.unstack().plot(y='Count')
g.set(ylabel='Count')
g.set_title("Popularity of Actor2 Country pair for RUS as Actor1 since 2015 - top {}".format(ile))
g.figure.set_size_inches(20,8)

# %%
s['%']= s.groupby(level=0).apply(lambda x:  100*x / x.sum())

g = s.unstack().plot(y='%')
g.set(ylabel='Count %')
g.set_title("Popularity of Actor2 Country pair for RUS as Actor1 since 2015 - top {}".format(ile))
g.figure.set_size_inches(20,8)
plt.savefig('text/fig/RUS/RUSactor2PairPercinTIME.png', bbox_inches='tight')
